# %%
import pandas as pd
df = pd.read_csv('data/Yearly_Projections_RB.csv', thousands=',')
df = df.convert_dtypes()
#df.info()
df.dtypes
# Out:
# Player     string
# Team       string
# ATT       Float64
# YDS       Float64
# TDS       Float64
# REC       Float64
# YDS.1     Float64
# TDS.1     Float64
# FL        Float64
# FPTS      Float64
# dtype: object

# %%
dfWeek = df.assign(RushYards = lambda x: ( x['YDS'] /17).astype(float),
                   RushTDs = lambda x: ( x['TDS'] /17), 
                   Rec = lambda x: ( x['REC'] /17),
                   PassYards = lambda x: ( x['YDS.1'] /17),
                   PassTDs = lambda x: ( x['TDS.1'] /17),
                   FL = lambda x: ( x['FL'] /17),
                   Pts =  lambda x: ( x['FPTS'] /17),
                   CalcPts = lambda x: ( x['FPTS'] /17),
                  )
dfWeek
# Out:
#                   Player  Team    ATT     YDS   TDS   REC  YDS.1  TDS.1  \
# 0                         <NA>   <NA>    <NA>  <NA>  <NA>   <NA>   <NA>
# 1    Christian McCaffrey   CAR  297.1  1301.6  12.0  93.8  760.1    4.3
# 2            Dalvin Cook   MIN  317.5  1491.6  13.0  54.9  473.3    2.0
# 3           Alvin Kamara    NO  206.9   941.4   9.7  81.0  688.6    3.5
# 4          Derrick Henry   TEN  343.0  1703.2  14.2  23.8  178.6    1.1
# ..                   ...   ...    ...     ...   ...   ...    ...    ...
# 174       Taquan Mizzell   NYG    0.9     3.7   0.0   0.9    5.4    0.0
# 175     Cullen Gillaspia   NYG    0.9     3.7   0.0   0.9    5.2    0.0
# 176       Tony Jones Jr.    NO    0.9     0.7   0.0   0.2    0.4    0.0
# 177                 <NA>  <NA>   <NA>    <NA>  <NA>  <NA>   <NA>   <NA>
# 178                 <NA>  <NA>   <NA>    <NA>  <NA>  <NA>   <NA>   <NA>
#
#            FL   FPTS   RushYards   RushTDs       Rec  PassYards   PassTDs  \
# ...
